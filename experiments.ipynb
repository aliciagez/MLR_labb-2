# %% [markdown]
# # Experimnet

# %%
import importlib
import model

importlib.reload(model)   # laddar om model.py från disk
print(dir(model))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'device', 'hidden_paramaters', 'in_put_paramaters', 'model', 'my_model', 'nn', 'out_put_paramaters', 'torch']

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from model import my_model

from check_env import device
from dataset import trainset, testset

# %%
#model 
print(my_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 #model
# ----> 2 my_model()
#
# File ~/labb/MLR_labb-2/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/labb/MLR_labb-2/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
# ...

# %%
import model
print(dir(model))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'device', 'hidden_paramaters', 'in_put_paramaters', 'model', 'my_model', 'nn', 'out_put_paramaters', 'torch']

# %%
#traning

train_loader_1 = DataLoader(trainset, batch_size=64, shuffle=True)
test_loader_1 = DataLoader(testset, batch_size=64, shuffle=False)

epochs = 10
