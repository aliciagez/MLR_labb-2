# %% [markdown]
# # Experimnet

# %%
import torch
import torch.optim as optim
from model import model 
from train import traning_loop
from check_env import device
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import torch
#       2 import torch.optim as optim
# ----> 3 from model import model
#       4 from train import traning_loop
#       5 from check_env import device
#
# File ~/labb/MLR_labb-2/model.py:12
#       8 out_put_paramaters = 128
#       9 amount_of_classes = 10
# ---> 12 model = nn.Sequential(nn.flatten(),nn.Linear(amout_data, in_put_paramaters), nn.ReLU(), nn.Linear(amount_of_classes)).to(device)
#
# AttributeError: module 'torch.nn' has no attribute 'flatten'
